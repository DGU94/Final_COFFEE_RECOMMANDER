# %%
import pandas as pd

# %%
S_coffee = pd.read_csv("/Users/david/Documents/GitHub/Final_project_DGU_LDU_COFFEE/3_coffee_compass_programme/clustered_coffee_df_WORKING.csv")
S_coffee_df = pd.DataFrame(S_coffee)
S_coffee_df
# Out:
#                                       coffee_name  rating  \
# 0                         Bolivia Manantial Gesha      93
# 1     Yellow Pacamara Carbonic Maceration Nanolot      92
# 2                      Ethiopia Gera Genji Challa      94
# 3                    Yirgacheffe Mengesha Natural      94
# 4              Tropical Summer Colombia La Sierra      93
# ...                                           ...     ...
# 4944                     Ethiopia Kemgin Espresso      92
# 4945                           Kenya AA Gandurine      93
# 4946                        Honduras David Mancia      94
# 4947                                 Doug E Fresh      90
# 4948                             Tangletown Blend      89
#
#                     rating_cat                    est_price  aftertaste  \
# 0     Very Good to Outstanding             $30.00/12 ounces           8
# 1     Very Good to Outstanding            $160.00/12 ounces           8
# 2     Very Good to Outstanding             $28.00/12 ounces           8
# 3     Very Good to Outstanding             $20.50/12 ounces           8
# 4     Very Good to Outstanding              $18.99/8 ounces           8
# ...                        ...                          ...         ...
# 4944  Very Good to Outstanding  $27.00/500 grams (17.6 oz.)           8
# 4945  Very Good to Outstanding             $19.45/16 ounces           8
# 4946  Very Good to Outstanding   $10.50/250 grams (8.8 oz.)           9
# 4947  Very Good to Outstanding             $13.99/16 ounces           8
# 4948                      Good             $11.95/16 ounces           8
#
#       aroma  body  flavor agtron  \
# 0         9     8       9  60/78
# 1         9     8       9  60/78
# 2         9     9       9  59/77
# 3         9     9       9  60/77
# 4         9     8       9  60/77
# ...     ...   ...     ...    ...
# 4944      9     7       9  48/60
# 4945      9     8       9  51/68
# 4946      9     8       9  57/73
# 4947      9     7       8  30/37
# 4948      8     7       8  63/86
#
#                                        blind_assessment  \
# 0     Richly aromatic, floral-toned. Magnolia, cocoa...
# 1     Crisply sweet-savory. White peach, hop flowers...
# 2     Delicately aromatic, complex. Lilac, cocoa nib...
# 3     High-toned, fruit-driven. Boysenberry, pear, c...
# 4     Fruit-driven, crisply chocolaty. Goji berry, d...
# ...                                                 ...
# 4944  Evaluated as espresso. In the small cup exhila...
# 4945  Balanced in aroma and cup. Floral tones are co...
# 4946  Deep, rich and pungent in aroma and cup. Round...
# 4947  Gently and richly charred cedar, dark chocolat...
# 4948  Lively citrus and berry in the aroma with hint...
#
#                                        coffee_origin  \
# 0                                  Caranavi, Bolivia
# 1                Matagalpa growing region, Nicaragua
# 2     Agaro Gera, Jimma Zone, Oromia State, Ethiopia
# 3      Yirgacheffe growing region, southern Ethiopia
# 4              La Sierra, Cauca Department, Colombia
# ...                                              ...
# 4944                                Western Ethiopia
# 4945                            South-central Kenya.
# 4946             Santa Barbara Department, Honduras.
# 4947                                  Not disclosed.
# 4948                                Central America.
#
#                                                   notes   roast_level  \
# 0     Produced by Angel Mamani Chambi, entirely of t...  Medium-Light
# 1     Produced by Benjamin Weiner at Finca Idealista...  Medium-Light
# 2     Ethiopia coffees like this one are largely pro...  Medium-Light
# 3     Produced at Mengesha Farm from selections of i...  Medium-Light
# 4     Produced by smallholding farmers from trees of...  Medium-Light
# ...                                                 ...           ...
# 4944  A special selection of hand sorted coffee from...        Medium
# 4945  Despite grower discontent and sporadic social ...        Medium
# 4946  Produced on the two hectare farm of David Manc...  Medium-Light
# 4947  Founded in 1993 near the famous Winter Park sk...     Very Dark
# 4948  Available in a 16-ounce valve bag at $11.95. C...         Light
#
#                              roaster        roaster_location  \
# 0         Red Rooster Coffee Roaster         Floyd, Virginia
# 1            Eccentricity Coffee Co.         Cleveland, Ohio
# 2                      Mostra Coffee   San Diego, California
# 3                      Regent Coffee    Glendale, California
# 4               Merge Coffee Company  Harrisonburg, Virginia
# ...                              ...                     ...
# 4944           Coava Coffee Roasters        Portland, Oregon
# 4945  Barrington Coffee Roasting Co.      Lee, Massachusetts
# 4946           Coava Coffee Roasters        Portland, Oregon
# 4947         Rocky Mountain Roastery        Fraser, Colorado
# 4948            Zoka Coffee Roasters     Seattle, Washington
#
#                                                     url  clusters  \
# 0     https://www.coffeereview.com/review/bolivia-ma...         2
# 1     https://www.coffeereview.com/review/brix-break...         2
# 2     https://www.coffeereview.com/review/ethiopia-g...         0
# 3     https://www.coffeereview.com/review/yirgacheff...         0
# 4     https://www.coffeereview.com/review/tropical-s...         2
# ...                                                 ...       ...
# 4944  https://www.coffeereview.com/review/ethiopia-k...         2
# 4945  https://www.coffeereview.com/review/kenya-aa-g...         2
# 4946  https://www.coffeereview.com/review/honduras-d...         2
# 4947  https://www.coffeereview.com/review/doug-e-fresh/         2
# 4948  https://www.coffeereview.com/review/tangletown...         1
#
#         max_match_key
# 0              Floral
# 1              Fruity
# 2               Sweet
# 3              Fruity
# 4               Berry
# ...               ...
# 4944          Citrusy
# 4945           Fruity
# 4946           Fruity
# 4947          Citrusy
# 4948  Acidity / Spicy
#
# [4949 rows x 18 columns]

# %% [markdown]
# ## NLP

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline
from nltk.corpus import stopwords

stop_words = list(stopwords.words('english')) 
stop_words
import string
import nltk
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /Users/david/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to /Users/david/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/david/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/david/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package tagsets to /Users/david/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %% [markdown]
# ## Bag of words

# %% [markdown]
# Grouping all texts into a dataframe "corpus"

# %%
corpus = S_coffee_df['blind_assessment']

# %%
# We put all the reviews in a lio
corpus=[]
for i in S_coffee_df['blind_assessment']:
    corpus.append(nltk.sent_tokenize(i))

# %%
# We flatten the list of lists into only one list
corpus = [sentence for sublist in corpus for sentence in sublist]

# %% [markdown]
# ## 1 - CLEANING TEXT

# %%
for i in range(len(corpus)):
    corpus[i] = corpus[i].lower()
    corpus[i] = re.sub(r'\W+',' ',corpus[i]) # Replace everything non-alpahnumeric by ' '
    corpus[i] = re.sub(r'\s+',' ',corpus[i]) # Replace one or more whitespaces by  ' '
    corpus[i] = re.sub(r'\d+',' ',corpus[i]) # Replace one or more digits by  ' '
    corpus[i] = re.sub(r'([a-z0-9+._-]+@[a-z0-9+._-]+\.[a-z0-9+_-]+)'," ", corpus[i]) # Replace e-mails by ' '
    # Replace urls by ''
    corpus[i] = re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', ' ' , corpus[i]) 
    # Replace html tags by ''
    corpus[i] = BeautifulSoup(corpus[i], 'html.parser').get_text().strip()

# %% [markdown]
# ## 2 - Tokenization

# %%
wordfreq = {}
for sentence in corpus:
    words = sentence.split()
    #tokens = nltk.word_tokenize(sentence) # To get the words, it can be also done with sentence.split()
    for word in words:
        if ( word not in wordfreq.keys() ): ## first time appearnce in the sentence
            wordfreq[word] = 1 # We initialize the corresponding counter
        else: ## if the world is already existed in the dictionalry 
            wordfreq[word] += 1 # We increase the corresponding counter

# %% [markdown]
# ## general COMMENTS........
# - sweet and toned appear more than one time in each review on average
# - in the count of each Hypernymsys : what about the one who has the same amount of values counted, we guess they have been choosing randomly

# %%
#We remove the stop words to reducing the corpus
from nltk.corpus import stopwords

stop_words = list(stopwords.words('english')) 
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
for i in range(len(stop_words)):
    stop_words[i] = re.sub(r"\s*'\s*\w*","",stop_words[i])

#stop_words = [word for word in list(np.unique(stop_words)) if len(word) > 1]
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'you',
#  'you',
#  'you',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'don',
#  'should',
#  'should',
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  'aren',
#  'couldn',
#  'couldn',
#  'didn',
#  'didn',
#  'doesn',
#  'doesn',
#  'hadn',
#  'hadn',
#  'hasn',
#  'hasn',
#  'haven',
#  'haven',
#  'isn',
#  'isn',
#  'ma',
#  'mightn',
#  'mightn',
#  'mustn',
#  'mustn',
#  'needn',
#  'needn',
#  'shan',
#  'shan',
#  'shouldn',
#  'shouldn',
#  'wasn',
#  'wasn',
#  'weren',
#  'weren',
#  'won',
#  'won',
#  'wouldn',
#  'wouldn']

# %%
corpus = [(wordfreq[key],key) for key in list(wordfreq.keys()) if key not in stop_words]

# %%
corpus.sort(reverse = True)

# Here we keep only the 100 most frequent words but it can be changed to another bigger value
corpus_freq = [(word[1],word[0]) for word in corpus[:301]] 
corpus_freq = corpus_freq[1:]
corpus_freq
# Out:
# [('finish', 4916),
#  ('cup', 4857),
#  ('mouthfeel', 4755),
#  ('aroma', 4661),
#  ('chocolate', 4016),
#  ('acidity', 3837),
#  ('toned', 3581),
#  ('notes', 2100),
#  ('structure', 1991),
#  ('syrupy', 1943),
#  ('tart', 1921),
#  ('cocoa', 1758),
#  ('fruit', 1744),
#  ('dark', 1661),
#  ('flowers', 1602),
#  ('richly', 1578),
#  ('cedar', 1517),
#  ('sweetly', 1491),
#  ('rich', 1400),
#  ('flavor', 1378),
#  ('crisp', 1298),
#  ('long', 1279),
#  ('nib', 1260),
#  ('like', 1205),
#  ('balanced', 1133),
#  ('floral', 1119),
#  ('zest', 1106),
#  ('savory', 1084),
#  ('juicy', 1044),
#  ('smooth', 987),
#  ('lightly', 967),
#  ('hint', 961),
#  ('gently', 947),
#  ('bright', 940),
#  ('resonant', 912),
#  ('milk', 904),
#  ('almond', 889),
#  ('fresh', 874),
#  ('satiny', 844),
#  ('full', 844),
#  ('drying', 833),
#  ('deeply', 832),
#  ('crisply', 824),
#  ('lemon', 811),
#  ('orange', 806),
#  ('deep', 805),
#  ('silky', 799),
#  ('consolidates', 796),
#  ('nut', 754),
#  ('complex', 741),
#  ('espresso', 739),
#  ('evaluated', 704),
#  ('chocolaty', 699),
#  ('cut', 693),
#  ('delicate', 671),
#  ('round', 661),
#  ('small', 651),
#  ('roasted', 646),
#  ('saturated', 645),
#  ('parts', 626),
#  ('pungent', 617),
#  ('hints', 599),
#  ('black', 598),
#  ('apricot', 578),
#  ('dried', 576),
#  ('honey', 575),
#  ('cacao', 575),
#  ('sandalwood', 569),
#  ('hazelnut', 561),
#  ('lively', 554),
#  ('brisk', 549),
#  ('short', 548),
#  ('fir', 530),
#  ('plush', 513),
#  ('cherry', 512),
#  ('aromatic', 482),
#  ('oak', 478),
#  ('three', 471),
#  ('around', 463),
#  ('carry', 462),
#  ('caramel', 461),
#  ('baking', 461),
#  ('delicately', 458),
#  ('citrus', 455),
#  ('wood', 454),
#  ('velvety', 448),
#  ('gentle', 446),
#  ('grapefruit', 429),
#  ('currant', 416),
#  ('bittersweet', 416),
#  ('tangerine', 408),
#  ('butter', 393),
#  ('narcissus', 386),
#  ('syrup', 378),
#  ('lavender', 376),
#  ('jasmine', 374),
#  ('undertones', 371),
#  ('though', 359),
#  ('vibrant', 358),
#  ('light', 352),
#  ('honeysuckle', 347),
#  ('magnolia', 341),
#  ('plum', 337),
#  ('spice', 336),
#  ('high', 330),
#  ('baker', 329),
#  ('pink', 315),
#  ('ripe', 310),
#  ('molasses', 310),
#  ('freesia', 307),
#  ('peach', 305),
#  ('centers', 302),
#  ('dry', 301),
#  ('quietly', 290),
#  ('lily', 284),
#  ('raspberry', 276),
#  ('vanilla', 273),
#  ('berry', 270),
#  ('rose', 259),
#  ('lilac', 259),
#  ('particular', 258),
#  ('leads', 258),
#  ('carries', 257),
#  ('creamy', 253),
#  ('red', 252),
#  ('quiet', 242),
#  ('tobacco', 241),
#  ('slightly', 241),
#  ('sweetness', 238),
#  ('sugar', 238),
#  ('layered', 237),
#  ('date', 237),
#  ('spicy', 236),
#  ('forward', 232),
#  ('supported', 231),
#  ('cashew', 230),
#  ('maple', 227),
#  ('buoyant', 221),
#  ('scorched', 220),
#  ('verbena', 219),
#  ('suggestions', 219),
#  ('intense', 216),
#  ('strawberry', 213),
#  ('soft', 207),
#  ('apple', 207),
#  ('mango', 205),
#  ('note', 202),
#  ('peppercorn', 200),
#  ('blossom', 197),
#  ('raisin', 196),
#  ('roundly', 193),
#  ('rather', 190),
#  ('powder', 190),
#  ('grape', 187),
#  ('gardenia', 185),
#  ('viscous', 183),
#  ('roast', 183),
#  ('pipe', 183),
#  ('blueberry', 181),
#  ('lime', 178),
#  ('lush', 177),
#  ('brown', 177),
#  ('walnut', 175),
#  ('fudge', 171),
#  ('tones', 166),
#  ('driven', 163),
#  ('coffee', 163),
#  ('wisteria', 162),
#  ('rounded', 161),
#  ('star', 160),
#  ('musk', 160),
#  ('agave', 159),
#  ('citrusy', 158),
#  ('blackberry', 158),
#  ('yet', 155),
#  ('two', 155),
#  ('pomegranate', 155),
#  ('marjoram', 151),
#  ('thyme', 146),
#  ('ken', 141),
#  ('clean', 141),
#  ('tea', 139),
#  ('dominates', 139),
#  ('pear', 137),
#  ('nougat', 137),
#  ('continued', 136),
#  ('guava', 135),
#  ('brandy', 133),
#  ('tamarind', 131),
#  ('blood', 131),
#  ('lychee', 130),
#  ('night', 128),
#  ('myrrh', 128),
#  ('bergamot', 127),
#  ('cinnamon', 126),
#  ('violet', 125),
#  ('rounding', 125),
#  ('florals', 123),
#  ('wine', 122),
#  ('body', 120),
#  ('pistachio', 119),
#  ('candied', 119),
#  ('ounce', 117),
#  ('brittle', 115),
#  ('complicated', 113),
#  ('nuanced', 111),
#  ('framed', 111),
#  ('toffee', 110),
#  ('pineapple', 110),
#  ('intricate', 110),
#  ('hop', 110),
#  ('brightly', 108),
#  ('fine', 107),
#  ('backgrounded', 106),
#  ('zesty', 105),
#  ('softly', 105),
#  ('persists', 105),
#  ('frankincense', 105),
#  ('complexity', 105),
#  ('earth', 104),
#  ('simple', 101),
#  ('dominate', 101),
#  ('complexly', 101),
#  ('keurig', 100),
#  ('buttery', 100),
#  ('rhododendron', 99),
#  ('toward', 98),
#  ('using', 97),
#  ('clove', 97),
#  ('green', 96),
#  ('flavors', 96),
#  ('character', 96),
#  ('leaning', 95),
#  ('brewing', 94),
#  ('resonantly', 93),
#  ('mulberry', 93),
#  ('lean', 92),
#  ('distinct', 92),
#  ('subtly', 91),
#  ('big', 91),
#  ('tartly', 90),
#  ('lingering', 90),
#  ('edge', 90),
#  ('brewed', 90),
#  ('stone', 89),
#  ('smoky', 89),
#  ('single', 89),
#  ('serve', 89),
#  ('device', 89),
#  ('bit', 89),
#  ('aromatics', 89),
#  ('serving', 88),
#  ('muted', 88),
#  ('capsule', 87),
#  ('blooming', 87),
#  ('herb', 86),
#  ('white', 85),
#  ('wild', 84),
#  ('pleasing', 84),
#  ('turns', 83),
#  ('moist', 83),
#  ('sage', 82),
#  ('cleanly', 82),
#  ('particularly', 81),
#  ('orangy', 81),
#  ('ginger', 81),
#  ('fruity', 81),
#  ('candy', 81),
#  ('plump', 80),
#  ('coconut', 80),
#  ('elegantly', 79),
#  ('almost', 77),
#  ('roasty', 76),
#  ('produce', 76),
#  ('intensely', 76),
#  ('centered', 76),
#  ('barrel', 76),
#  ('amber', 75),
#  ('butterscotch', 74),
#  ('fades', 73),
#  ('elegant', 73),
#  ('perhaps', 72),
#  ('multi', 72),
#  ('banana', 72),
#  ('nectarine', 71),
#  ('co', 71),
#  ('laden', 68),
#  ('pungently', 67),
#  ('pecan', 67),
#  ('fig', 67),
#  ('cappuccino', 66),
#  ('spices', 65),
#  ('expressed', 65),
#  ('balance', 65),
#  ('slight', 64),
#  ('persimmon', 64),
#  ('lemony', 64),
#  ('flower', 64),
#  ('anise', 64),
#  ('suggestion', 63)]

# %% [markdown]
# **Lemmatization**<br />
#
# It will kind of creat cluster of words of the same emotional side

# %%
# We would use Lemmatizer to check if we could cluster words that share similar emotions
#from nltk.stem import WordNetLemmatizer
#nltk.download('omw-1.4')
#lem = WordNetLemmatizer()

#corpus_freq = [(lem.lemmatize(word[0]),word[1]) for word in corpus_freq]
#corpus_freq

# %% [markdown]
# **Stemming** <br />
#
# to reduce the number of same "root words" and be able to look for this extension all over the text and group them into once "root words".

# %%
# We manually remove what we sens should not be pertinent enough
#remove_words = set(['cup', 'finish', 'mouthfeel', 'toned', 'structure', 'notes', 'nib', 'zest', 'long', 'resonant', 'like', 'dried', 'plush', 'baking', 'fresh', 'high', 'hint', 'centers', 'leads', 'hints', 'pipe', 'suggestions', 'lead', 'cane', 'using', 'edge', 'edged', 'amplified', 'support', 'throughout''cup', 'coulis', 'satisfying', 'confident', 'shot', 'engaging', 'inviting', 'golden', 'cleanly', 'yet', 'meyer', 'tone', 'though', 'intricately', 'concord', 'bing', 'flavor', 'around', 'gently', 'center', 'short', 'cut', 'pink', 'red', 'small', 'supported', 'evaluated', 'star', 'baker', 'driven', 'part', 'three', 'leaning', 'multi', 'suggestion', 'carry', 'centered', 'nuanced', 'pert', 'note', 'deeply', 'full', 'consolidates',  'finish', 'mouthfeel', 'toned', 'structure', 'notes', 'nib', 'zest', 'long', 'resonant', 'like', 'dried', 'plush', 'baking', 'fresh', 'high', 'hint', 'centers', 'leads', 'hints', 'pipe', 'suggestions', 'lead', 'particular', 'aroma', 'lyrically', 'promise', 'resonantly', 'cane', 'using', 'edge', 'edged', 'amplified', 'support', 'throughout', 'richly'])
remove_words = set(['cup', 'finish', 'mouthfeel', 'toned', 'structure', 'notes', 'nib', 'zest', 'long', 'resonant', 'like', 'dried', 'plush', 'baking', 'fresh', 'high', 'hint', 'centers', 'leads', 'hints', 'pipe', 'suggestions', 'lead', 'cane', 'using', 'edge', 'edged', 'amplified', 'support', 'throughout', 'cup', 'coulis', 'satisfying', 'confident', 'shot', 'engaging', 'inviting', 'golden', 'cleanly', 'yet', 'meyer', 'tone', 'though', 'intricately', 'concord', 'bing', 'flavor', 'around', 'gently', 'center', 'short', 'cut', 'pink', 'red', 'small', 'supported', 'evaluated', 'star', 'baker', 'driven', 'part', 'three', 'leaning', 'multi', 'suggestion', 'carry', 'centered', 'nuanced', 'pert', 'note', 'deeply', 'full', 'consolidates', 'finish', 'mouthfeel', 'toned', 'structure', 'notes', 'nib', 'zest', 'long', 'resonant', 'like', 'dried', 'plush', 'baking', 'fresh', 'high', 'hint', 'centers', 'leads', 'hints', 'pipe', 'suggestions', 'lead', 'particular', 'aroma', 'lyrically', 'promise', 'resonantly', 'cane', 'using', 'edge', 'edged', 'amplified', 'support', 'throughout', 'richly', 'deep', 'brisk', 'vibrant', 'dark','lively', 'espresso','parts', 'balanced', 'rich', 'black', 'round', 'intensely', 'pungent', 'fine', 'savory'])

# %%
corpus_freq = [(key, freq) for key,freq in corpus_freq if key not in remove_words]
corpus_freq
# Out:
# [('chocolate', 4016),
#  ('acidity', 3837),
#  ('syrupy', 1943),
#  ('tart', 1921),
#  ('cocoa', 1758),
#  ('fruit', 1744),
#  ('flowers', 1602),
#  ('cedar', 1517),
#  ('sweetly', 1491),
#  ('crisp', 1298),
#  ('floral', 1119),
#  ('juicy', 1044),
#  ('smooth', 987),
#  ('lightly', 967),
#  ('bright', 940),
#  ('milk', 904),
#  ('almond', 889),
#  ('satiny', 844),
#  ('drying', 833),
#  ('crisply', 824),
#  ('lemon', 811),
#  ('orange', 806),
#  ('silky', 799),
#  ('nut', 754),
#  ('complex', 741),
#  ('chocolaty', 699),
#  ('delicate', 671),
#  ('roasted', 646),
#  ('saturated', 645),
#  ('apricot', 578),
#  ('honey', 575),
#  ('cacao', 575),
#  ('sandalwood', 569),
#  ('hazelnut', 561),
#  ('lively', 554),
#  ('brisk', 549),
#  ('fir', 530),
#  ('cherry', 512),
#  ('aromatic', 482),
#  ('oak', 478),
#  ('caramel', 461),
#  ('delicately', 458),
#  ('citrus', 455),
#  ('wood', 454),
#  ('velvety', 448),
#  ('gentle', 446),
#  ('grapefruit', 429),
#  ('currant', 416),
#  ('bittersweet', 416),
#  ('tangerine', 408),
#  ('butter', 393),
#  ('narcissus', 386),
#  ('syrup', 378),
#  ('lavender', 376),
#  ('jasmine', 374),
#  ('undertones', 371),
#  ('vibrant', 358),
#  ('light', 352),
#  ('honeysuckle', 347),
#  ('magnolia', 341),
#  ('plum', 337),
#  ('spice', 336),
#  ('ripe', 310),
#  ('molasses', 310),
#  ('freesia', 307),
#  ('peach', 305),
#  ('dry', 301),
#  ('quietly', 290),
#  ('lily', 284),
#  ('raspberry', 276),
#  ('vanilla', 273),
#  ('berry', 270),
#  ('rose', 259),
#  ('lilac', 259),
#  ('carries', 257),
#  ('creamy', 253),
#  ('quiet', 242),
#  ('tobacco', 241),
#  ('slightly', 241),
#  ('sweetness', 238),
#  ('sugar', 238),
#  ('layered', 237),
#  ('date', 237),
#  ('spicy', 236),
#  ('forward', 232),
#  ('cashew', 230),
#  ('maple', 227),
#  ('buoyant', 221),
#  ('scorched', 220),
#  ('verbena', 219),
#  ('intense', 216),
#  ('strawberry', 213),
#  ('soft', 207),
#  ('apple', 207),
#  ('mango', 205),
#  ('peppercorn', 200),
#  ('blossom', 197),
#  ('raisin', 196),
#  ('roundly', 193),
#  ('rather', 190),
#  ('powder', 190),
#  ('grape', 187),
#  ('gardenia', 185),
#  ('viscous', 183),
#  ('roast', 183),
#  ('blueberry', 181),
#  ('lime', 178),
#  ('lush', 177),
#  ('brown', 177),
#  ('walnut', 175),
#  ('fudge', 171),
#  ('tones', 166),
#  ('coffee', 163),
#  ('wisteria', 162),
#  ('rounded', 161),
#  ('musk', 160),
#  ('agave', 159),
#  ('citrusy', 158),
#  ('blackberry', 158),
#  ('two', 155),
#  ('pomegranate', 155),
#  ('marjoram', 151),
#  ('thyme', 146),
#  ('ken', 141),
#  ('clean', 141),
#  ('tea', 139),
#  ('dominates', 139),
#  ('pear', 137),
#  ('nougat', 137),
#  ('continued', 136),
#  ('guava', 135),
#  ('brandy', 133),
#  ('tamarind', 131),
#  ('blood', 131),
#  ('lychee', 130),
#  ('night', 128),
#  ('myrrh', 128),
#  ('bergamot', 127),
#  ('cinnamon', 126),
#  ('violet', 125),
#  ('rounding', 125),
#  ('florals', 123),
#  ('wine', 122),
#  ('body', 120),
#  ('pistachio', 119),
#  ('candied', 119),
#  ('ounce', 117),
#  ('brittle', 115),
#  ('complicated', 113),
#  ('framed', 111),
#  ('toffee', 110),
#  ('pineapple', 110),
#  ('intricate', 110),
#  ('hop', 110),
#  ('brightly', 108),
#  ('backgrounded', 106),
#  ('zesty', 105),
#  ('softly', 105),
#  ('persists', 105),
#  ('frankincense', 105),
#  ('complexity', 105),
#  ('earth', 104),
#  ('simple', 101),
#  ('dominate', 101),
#  ('complexly', 101),
#  ('keurig', 100),
#  ('buttery', 100),
#  ('rhododendron', 99),
#  ('toward', 98),
#  ('clove', 97),
#  ('green', 96),
#  ('flavors', 96),
#  ('character', 96),
#  ('brewing', 94),
#  ('mulberry', 93),
#  ('lean', 92),
#  ('distinct', 92),
#  ('subtly', 91),
#  ('big', 91),
#  ('tartly', 90),
#  ('lingering', 90),
#  ('brewed', 90),
#  ('stone', 89),
#  ('smoky', 89),
#  ('single', 89),
#  ('serve', 89),
#  ('device', 89),
#  ('bit', 89),
#  ('aromatics', 89),
#  ('serving', 88),
#  ('muted', 88),
#  ('capsule', 87),
#  ('blooming', 87),
#  ('herb', 86),
#  ('white', 85),
#  ('wild', 84),
#  ('pleasing', 84),
#  ('turns', 83),
#  ('moist', 83),
#  ('sage', 82),
#  ('particularly', 81),
#  ('orangy', 81),
#  ('ginger', 81),
#  ('fruity', 81),
#  ('candy', 81),
#  ('plump', 80),
#  ('coconut', 80),
#  ('elegantly', 79),
#  ('almost', 77),
#  ('roasty', 76),
#  ('produce', 76),
#  ('barrel', 76),
#  ('amber', 75),
#  ('butterscotch', 74),
#  ('fades', 73),
#  ('elegant', 73),
#  ('perhaps', 72),
#  ('banana', 72),
#  ('nectarine', 71),
#  ('co', 71),
#  ('laden', 68),
#  ('pungently', 67),
#  ('pecan', 67),
#  ('fig', 67),
#  ('cappuccino', 66),
#  ('spices', 65),
#  ('expressed', 65),
#  ('balance', 65),
#  ('slight', 64),
#  ('persimmon', 64),
#  ('lemony', 64),
#  ('flower', 64),
#  ('anise', 64)]

# %%
#corpus_final = dict(corpus_final)
# my_tuple = corpus_final
# my_dict = dict(enumerate(my_tuple))
#print(corpus_final)

# %%
corpus_df = pd.DataFrame(corpus)
corpus_df.to_csv('corpus_final.csv')

# %%
corpus_df
# Out:
#          0            1
# 0     4981        sweet
# 1     4916       finish
# 2     4857          cup
# 3     4755    mouthfeel
# 4     4661        aroma
# ...    ...          ...
# 2802     1     accepted
# 2803     1     accented
# 2804     1   abundantly
# 2805     1  absorbingly
# 2806     1     abruptly
#
# [2807 rows x 2 columns]

# %% [markdown]
# Now we keep the most frequent word to start having a final vision.

# %% [markdown]
# **To make it even more accurate we gonna remove some irrelevant words manually**

# %%
corpus_freq
# Out:
# [('chocolate', 4016),
#  ('acidity', 3837),
#  ('syrupy', 1943),
#  ('tart', 1921),
#  ('cocoa', 1758),
#  ('fruit', 1744),
#  ('flowers', 1602),
#  ('cedar', 1517),
#  ('sweetly', 1491),
#  ('crisp', 1298),
#  ('floral', 1119),
#  ('juicy', 1044),
#  ('smooth', 987),
#  ('lightly', 967),
#  ('bright', 940),
#  ('milk', 904),
#  ('almond', 889),
#  ('satiny', 844),
#  ('drying', 833),
#  ('crisply', 824),
#  ('lemon', 811),
#  ('orange', 806),
#  ('silky', 799),
#  ('nut', 754),
#  ('complex', 741),
#  ('espresso', 739),
#  ('chocolaty', 699),
#  ('delicate', 671),
#  ('roasted', 646),
#  ('saturated', 645),
#  ('parts', 626),
#  ('apricot', 578),
#  ('honey', 575),
#  ('cacao', 575),
#  ('sandalwood', 569),
#  ('hazelnut', 561),
#  ('lively', 554),
#  ('brisk', 549),
#  ('fir', 530),
#  ('cherry', 512),
#  ('aromatic', 482),
#  ('oak', 478),
#  ('caramel', 461),
#  ('delicately', 458),
#  ('citrus', 455),
#  ('wood', 454),
#  ('velvety', 448),
#  ('gentle', 446),
#  ('grapefruit', 429),
#  ('currant', 416),
#  ('bittersweet', 416),
#  ('tangerine', 408),
#  ('butter', 393),
#  ('narcissus', 386),
#  ('syrup', 378),
#  ('lavender', 376),
#  ('jasmine', 374),
#  ('undertones', 371),
#  ('vibrant', 358),
#  ('light', 352),
#  ('honeysuckle', 347),
#  ('magnolia', 341),
#  ('plum', 337),
#  ('spice', 336),
#  ('ripe', 310),
#  ('molasses', 310),
#  ('freesia', 307),
#  ('peach', 305),
#  ('dry', 301),
#  ('quietly', 290),
#  ('lily', 284),
#  ('raspberry', 276),
#  ('vanilla', 273),
#  ('berry', 270),
#  ('rose', 259),
#  ('lilac', 259),
#  ('carries', 257),
#  ('creamy', 253),
#  ('quiet', 242),
#  ('tobacco', 241),
#  ('slightly', 241),
#  ('sweetness', 238),
#  ('sugar', 238),
#  ('layered', 237),
#  ('date', 237),
#  ('spicy', 236),
#  ('forward', 232),
#  ('cashew', 230),
#  ('maple', 227),
#  ('buoyant', 221),
#  ('scorched', 220),
#  ('verbena', 219),
#  ('intense', 216),
#  ('strawberry', 213),
#  ('soft', 207),
#  ('apple', 207),
#  ('mango', 205),
#  ('peppercorn', 200),
#  ('blossom', 197),
#  ('raisin', 196),
#  ('roundly', 193),
#  ('rather', 190),
#  ('powder', 190),
#  ('grape', 187),
#  ('gardenia', 185),
#  ('viscous', 183),
#  ('roast', 183),
#  ('blueberry', 181),
#  ('lime', 178),
#  ('lush', 177),
#  ('brown', 177),
#  ('walnut', 175),
#  ('fudge', 171),
#  ('tones', 166),
#  ('coffee', 163),
#  ('wisteria', 162),
#  ('rounded', 161),
#  ('musk', 160),
#  ('agave', 159),
#  ('citrusy', 158),
#  ('blackberry', 158),
#  ('two', 155),
#  ('pomegranate', 155),
#  ('marjoram', 151),
#  ('thyme', 146),
#  ('ken', 141),
#  ('clean', 141),
#  ('tea', 139),
#  ('dominates', 139),
#  ('pear', 137),
#  ('nougat', 137),
#  ('continued', 136),
#  ('guava', 135),
#  ('brandy', 133),
#  ('tamarind', 131),
#  ('blood', 131),
#  ('lychee', 130),
#  ('night', 128),
#  ('myrrh', 128),
#  ('bergamot', 127),
#  ('cinnamon', 126),
#  ('violet', 125),
#  ('rounding', 125),
#  ('florals', 123),
#  ('wine', 122),
#  ('body', 120),
#  ('pistachio', 119),
#  ('candied', 119),
#  ('ounce', 117),
#  ('brittle', 115),
#  ('complicated', 113),
#  ('framed', 111),
#  ('toffee', 110),
#  ('pineapple', 110),
#  ('intricate', 110),
#  ('hop', 110),
#  ('brightly', 108),
#  ('backgrounded', 106),
#  ('zesty', 105),
#  ('softly', 105),
#  ('persists', 105),
#  ('frankincense', 105),
#  ('complexity', 105),
#  ('earth', 104),
#  ('simple', 101),
#  ('dominate', 101),
#  ('complexly', 101),
#  ('keurig', 100),
#  ('buttery', 100),
#  ('rhododendron', 99),
#  ('toward', 98),
#  ('clove', 97),
#  ('green', 96),
#  ('flavors', 96),
#  ('character', 96),
#  ('brewing', 94),
#  ('mulberry', 93),
#  ('lean', 92),
#  ('distinct', 92),
#  ('subtly', 91),
#  ('big', 91),
#  ('tartly', 90),
#  ('lingering', 90),
#  ('brewed', 90),
#  ('stone', 89),
#  ('smoky', 89),
#  ('single', 89),
#  ('serve', 89),
#  ('device', 89),
#  ('bit', 89),
#  ('aromatics', 89),
#  ('serving', 88),
#  ('muted', 88),
#  ('capsule', 87),
#  ('blooming', 87),
#  ('herb', 86),
#  ('white', 85),
#  ('wild', 84),
#  ('pleasing', 84),
#  ('turns', 83),
#  ('moist', 83),
#  ('sage', 82),
#  ('particularly', 81),
#  ('orangy', 81),
#  ('ginger', 81),
#  ('fruity', 81),
#  ('candy', 81),
#  ('plump', 80),
#  ('coconut', 80),
#  ('elegantly', 79),
#  ('almost', 77),
#  ('roasty', 76),
#  ('produce', 76),
#  ('barrel', 76),
#  ('amber', 75),
#  ('butterscotch', 74),
#  ('fades', 73),
#  ('elegant', 73),
#  ('perhaps', 72),
#  ('banana', 72),
#  ('nectarine', 71),
#  ('co', 71),
#  ('laden', 68),
#  ('pungently', 67),
#  ('pecan', 67),
#  ('fig', 67),
#  ('cappuccino', 66),
#  ('spices', 65),
#  ('expressed', 65),
#  ('balance', 65),
#  ('slight', 64),
#  ('persimmon', 64),
#  ('lemony', 64),
#  ('flower', 64),
#  ('anise', 64)]

# %% [markdown]
# **We assigne each word into their most relevant hypernym groups**

# %% [markdown]
# We try to manually put the words into there hypernyms

# %%
# Define the hypernym groups
hypernymsy = {
    'Fruity': ['apricot', 'cherry', 'date', 'plum', 'peach', 'tamarind', 'bergamot', 'grape', 'pear', 'persimmon', 'fruity', 'raisin', 'watermelon', 'plump', 'fig', 'tomato'],
    'Tropical': ['mango', 'pomegranate', 'guava', 'pineapple', 'lychee', 'coconut', 'tropical', 'passionfruit'],
    'Citrusy': ['lemon','citrusy', 'grapefruit', 'tangerine', 'citrus', 'orange', 'lime', 'amber', 'pomelo'],
    'Woody': ['cedar', 'oak', 'fir', 'wood', 'plumeria', 'elm', 'sandalwood', 'mushroom', 'earth'],
    'Berry': ['currant', 'raspberry', 'berry', 'blueberry', 'wine', 'mulberry', 'winy', 'winey', 'strawberry', 'goji', 'grappa'],
    'Sweet': ['caramel', 'nougat','toffee', 'candy', 'candied', 'butterscotch', 'fudge','tart', 'syrupy', 'syrup', 'honey', 'molasses', 'sugar', 'rum', 'jam', 'nutella', 'brandy', 'pie', 'maple', 'agave'],
    'Nutty': ['almond', 'hazelnut', 'nut', 'cashew', 'pistachio', 'macadamia', 'walnut', 'nutty'],
    'Creamy': ['butter', 'milk', 'creamy', 'yogurt'],
    'Herbal': ['narcissus', 'freesia', 'honeysuckle' 'thyme', 'marjoram', 'wisteria', 'musk', 'tobacco', 'herbaceous', 'herb', 'spearmint', 'cardamom', 'lemongrass', 'balm'],
    'Chocolaty': ['chocolate', 'cocoa', 'chocolaty', 'cacao'],
    'Floral': ['floral', 'flower', 'jasmine', 'magnolia', 'verbena', 'lilac', 'gardenia', 'lavender', 'blossom', 'lily', 'florals', 'rose', 'rhododendron', 'violet', 'hibiscus'],
    'Delicate': ['juicy', 'satiny', 'smooth', 'delicate', 'silky', 'dry' ,'light'],
    'Bold': ['saturated', 'aromatic', 'complex', 'smoky', 'scorched', 'viscous',  'crisp', 'crisply'],
    'Acidity / Spicy': ['acidity', 'bittersweet', 'hop', 'zesty', 'spice', 'peppercorn', 'frankincense', 'spicy', 'cinnamon', 'clove', 'salted', 'tangy', 'ginger'],
}

# %% [markdown]
# **We drop the following words which only re-enforce or qualify an already existing label.**
#
# deep<br>
# dark<br>
# balanced<br>
# rich<br>
# black<br>
# round<br>
# intensely<br>
# pungent<br>
# fine<br>
# savory<br>
# In Texture, we changed 'drying' into 'dry' and remove 'dry' from Character.
#
#
# We also remove too generic words like : 'Fruit', 'Sweet/ly/ness'

# %%
# create a dictionary to store the match counts per key
match_counts = {}

# loop over the keys and values in the dictionary
for key, value in hypernymsy.items():
    # count the number of matches for the current key
    counts = []
    for row in S_coffee_df["blind_assessment"]:
        # step 1
        my_column_words = row.lower()
        match_count = sum(1 for word in value if word in my_column_words)
        counts.append(match_count)
    # store the match counts for the current key in the dictionary
    match_counts[key] = counts

# add the match counts as new columns to the data frame
for key, value in match_counts.items():
    S_coffee_df[f"{key}"] = value
    
# add new column with key that has the most matches
max_match_keys = []
for i in range(len(S_coffee_df)):
    row_counts = [S_coffee_df[f"{key}"][i] for key in hypernymsy.keys()]
    max_match_key = max(hypernymsy.keys(), key=lambda x: row_counts[list(hypernymsy.keys()).index(x)])
    max_match_keys.append(max_match_key)

S_coffee_df["max_match_key"] = max_match_keys

S_coffee_df = pd.DataFrame(S_coffee_df)

# %%
# checking to see how many unique values are in the "max_match_key"
S_coffee_df["max_match_key"].value_counts()
# Out:
# Sweet              1620
# Texture            1046
# Fruity              454
# Woody               306
# Floral              276
# Citrusy             274
# Berry               239
# Nutty               214
# Acidity / Spicy     174
# Chocolaty           120
# Character            65
# Creamy               62
# Herbal               46
# Tropical             42
# Candy                11
# Name: max_match_key, dtype: int64

# %%
S_coffee_df.to_csv('features_flavor.csv')

# %%
import pandas as pd
from fuzzywuzzy import process

features = []
for i in range(3):
    feature = input(f"Enter feature {i+1}: ")
    while feature not in S_coffee_df.columns:
        # if feature is not in columns, try to find the closest match using FuzzyWuzzy
        match = process.extractOne(feature, S_coffee_df.columns)[0]
        print(f"Invalid feature name. Did you mean '{match}'?")
        feature = match
    features.append(feature)

# print the selected features
print(f"Selected features: {features}")

# filter the DataFrame to include only rows with at least 1 in each of the 3 features
filtered_df = S_coffee_df[(S_coffee_df[features[0]] >= 1) & (S_coffee_df[features[1]] >= 1) & (S_coffee_df[features[2]] >= 1)]

# add a column for the sum of the 3 features
filtered_df['score'] = filtered_df[features[0]] + filtered_df[features[1]] + filtered_df[features[2]]

# sort the filtered DataFrame by the combined score
sorted_df = filtered_df.sort_values(by='score', ascending=False)

# print the top 5 rows with the highest combined score
print(sorted_df.head(20))
# Out:
# Enter feature 1: canda
# Invalid feature name. Did you mean 'Candy'?
# Enter feature 2: herbal
# Invalid feature name. Did you mean 'Herbal'?
# Enter feature 3: Nutty
# Selected features: ['Candy', 'Herbal', 'Nutty']
#                                             coffee_name  rating  \
# 140                     Nicaragua Flor de Dalia Natural      92
# 2461                        Ethiopia Shakiso, Mora Mora      92
# 2840                            Breakfast Blend (K-Cup)      87
# 1601                                       Jacmel Haiti      90
# 2315                              Adanech Ethiopia Guji      91
# 1926                            Kebele Village Espresso      94
# 331                             Guatemala Flor del Café      93
# 2301                       Kenya Baragwi Thimu Peaberry      94
# 2097                 Peru Finca Ecológica Agua Colorada      93
# 2094                                  Costa Coast Blend      92
# 1677                              Honduras Buenos Aires      92
# 1990                                    Signature Blend      91
# 2329                         Guatemala Pacamara Natural      95
# 1909                Mario Aguilar Grand Cru El Salvador      91
# 1765                           Ethiopia Kochere Natural      94
# 1742                                    ASOPAP Colombia      90
# 1936  Panama Hacienda La Esmeralda Super Mario 6 Geisha      95
# 2479                                Three Pillars Blend      92
# 828                             Red Clay Espresso Blend      92
# 2521                                      Jarama Rwanda      92
#
#                     rating_cat          est_price  aftertaste  aroma  body  \
# 140   Very Good to Outstanding   $18.00/12 ounces           8      8     9
# 2461  Very Good to Outstanding   $19.00/10 ounces           8      9     8
# 2840                      Good   $14.99/24 K-cups           7      8     7
# 1601  Very Good to Outstanding    $15.00/8 ounces           8      8     8
# 2315  Very Good to Outstanding   $18.00/12 ounces           8      8     8
# 1926  Very Good to Outstanding   $17.10/12 ounces           8      9     9
# 331   Very Good to Outstanding   $17.00/12 ounces           8      9     9
# 2301  Very Good to Outstanding   $19.50/12 ounces           8      9     9
# 2097  Very Good to Outstanding   $16.49/12 ounces           8      9     8
# 2094  Very Good to Outstanding   $21.00/16 ounces           8      8     9
# 1677  Very Good to Outstanding   $19.00/12 ounces           8      9     8
# 1990  Very Good to Outstanding  NT $280/454 grams           8      8     8
# 2329               Exceptional  NT $1450/8 ounces           9      9     9
# 1909  Very Good to Outstanding   $25.00/12 ounces           8      8     8
# 1765  Very Good to Outstanding   $18.00/12 ounces           8      9     9
# 1742  Very Good to Outstanding   $15.90/12 ounces           8      8     8
# 1936               Exceptional    $60.00/8 ounces           9      9     9
# 2479  Very Good to Outstanding   $16.75/12 ounces           8      8     9
# 828   Very Good to Outstanding   $14.99/12 ounces           9      8     8
# 2521  Very Good to Outstanding   $19.95/12 ounces           8      8     9
#
#       flavor agtron                                   blind_assessment  ...  \
# 140        9  62/78  Gently fruit-forward, sweetly nut-toned. Rice ...  ...
# 2461       9  59/68  Delicate, sweetly spice-toned. Ripe peach, cin...  ...
# 2840       8   0/56  (As brewed in a Keurig 2.0 K500 Series single-...  ...
# 1601       9  54/68  Crisply sweet, caramel- and nut-toned. Nougat,...  ...
# 2315       9  58/84  Sweetly herbaceous, richly cocoa-toned. Baker’...  ...
# 1926       9  52/70  Evaluated as espresso. Bright, sweetly tart, f...  ...
# 331        9  59/77  Richly sweet, nut-toned. Fig Newton, almond no...  ...
# 2301       9  52/74  Spiced toned, richly sweet. Red currant, almon...  ...
# 2097       9  58/84  Richly sweet, floral-toned. Wisteria, roasted ...  ...
# 2094       9  52/78  Floral-toned, crisp, deeply sweet. Dried straw...  ...
# 1677       9  58/74  Richly bittersweet, nut-toned. Caramelized haz...  ...
# 1990       9  52/68  Crisply sweet, nut-toned. Almond, caramel, fre...  ...
# 2329       9  57/77  Complex, sweetly tart, spice-toned. Peach, fin...  ...
# 1909       9  55/66  Deeply sweet, pungent, with a very slight roas...  ...
# 1765       9  52/74  Richly bittersweet, complexly fruit-toned. Cho...  ...
# 1742       8  55/77  Crisply sweet, cocoa-toned. Cocoa nib, almond ...  ...
# 1936       9  51/71  Impeccably floral and cocoa-toned with a savor...  ...
# 2479       9  55/78  Delicately sweet, fruit-toned. Blueberry, cara...  ...
# 828        9  47/63  Evaluated as espresso. Richly sweet-savory, un...  ...
# 2521       9  51/72  Deeply sweet, quietly rich. Cashew, butterscot...  ...
#
#      Creamy Herbal Chocolaty Floral Texture Character  Acidity / Spicy  \
# 140       1      2         0      1       0         0                1
# 2461      1      2         0      0       2         1                4
# 2840      0      1         0      0       3         0                2
# 1601      0      1         0      0       4         1                1
# 2315      0      2         2      1       0         0                2
# 1926      1      1         0      2       1         0                0
# 331       0      1         0      1       2         0                1
# 2301      0      2         0      1       3         1                2
# 2097      0      2         2      1       3         0                1
# 2094      2      1         0      2       1         0                0
# 1677      0      1         1      1       1         0                2
# 1990      0      1         0      0       3         0                1
# 2329      0      1         2      0       1         1                2
# 1909      0      1         1      1       0         0                0
# 1765      0      1         1      1       0         1                2
# 1742      0      2         1      1       2         1                1
# 1936      1      1         2      1       2         0                3
# 2479      0      1         0      2       3         0                1
# 828       1      1         0      0       0         0                1
# 2521      1      1         0      1       3         1                1
#
#      Delicate  Bold  score
# 140         0     0      6
# 2461        3     0      5
# 2840        4     0      5
# 1601        3     2      5
# 2315        0     0      5
# 1926        0     1      5
# 331         0     2      5
# 2301        2     2      4
# 2097        1     2      4
# 2094        0     1      4
# 1677        2     0      4
# 1990        1     2      4
# 2329        1     1      4
# 1909        1     0      4
# 1765        0     1      4
# 1742        1     2      4
# 1936        1     1      4
# 2479        2     2      4
# 828         0     0      4
# 2521        2     2      4
#
# [20 rows x 36 columns]
# /var/folders/d0/kyjzvmwn3fdgc5m0t8snt0nm0000gn/T/ipykernel_44345/992923586.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['score'] = filtered_df[features[0]] + filtered_df[features[1]] + filtered_df[features[2]]
