# %%
import pandas as pd

# %%
Bier_num = Bier_df.select_dtypes(include=np.number)
Bier_num
Bier_num.columns
# Out:
# Index(['brewery_id', 'review_time', 'review_overall', 'review_aroma',
#        'review_appearance', 'review_palate', 'review_taste', 'beer_abv',
#        'beer_beerid'],
#       dtype='object')

# %%
coffee_an = pd.read_csv("/Users/david/Documents/GitHub/Final_project_DGU_LDU/DATA/coffee_analysis.csv")
coffee_an_df = pd.DataFrame(coffee_an)
coffee_df.info
# Out:
# <bound method DataFrame.info of                             name                    roaster         roast  \
# 0        “Sweety” Espresso Blend                     A.R.C.  Medium-Light
# 1           Flora Blend Espresso                     A.R.C.  Medium-Light
# 2       Ethiopia Shakiso Mormora               Revel Coffee  Medium-Light
# 3             Ethiopia Suke Quto                Roast House  Medium-Light
# 4     Ethiopia Gedeb Halo Beriti  Big Creek Coffee Roasters        Medium
# ...                          ...                        ...           ...
# 2090              Finca Patzibir               El Gran Cafe  Medium-Light
# 2091             Proyecto Aurora               El Gran Cafe  Medium-Light
# 2092            Finca El Potrero               El Gran Cafe  Medium-Light
# 2093    Chacayá Santiago Atitlán               El Gran Cafe  Medium-Light
# 2094              Espresso No. 3               El Gran Cafe  Medium-Light
#
# ...

# %%
sim_cof = pd.read_csv("/Users/david/Documents/GitHub/Final_project_DGU_LDU/DATA/simplified_coffee.csv")
sim_cof_df = pd.DataFrame(coffee)
sim_cof
# Out:
#                                   name                     roaster  \
# 0             Ethiopia Shakiso Mormora                Revel Coffee
# 1                   Ethiopia Suke Quto                 Roast House
# 2           Ethiopia Gedeb Halo Beriti   Big Creek Coffee Roasters
# 3              Ethiopia Kayon Mountain  Red Rooster Coffee Roaster
# 4     Ethiopia Gelgelu Natural Organic   Willoughby's Coffee & Tea
# ...                                ...                         ...
# 1241                    Finca Patzibir                El Gran Cafe
# 1242                   Proyecto Aurora                El Gran Cafe
# 1243                  Finca El Potrero                El Gran Cafe
# 1244          Chacayá Santiago Atitlán                El Gran Cafe
# 1245                    Espresso No. 3                El Gran Cafe
#
#              roast    loc_country     origin  100g_USD  rating    review_date  \
# 0     Medium-Light  United States   Ethiopia      4.70      92  November 2017
# ...

# %%
Base = pd.read_csv("/Users/david/Documents/GitHub/Final_project_DGU_LDU/DATA/BASE_coffee_df.csv")
Base_df = pd.DataFrame(Base)
Base_df
# Out:
#                        location  \
# 0            Madison, Wisconsin
# 1         San Diego, California
# 2          Glendale, California
# 3          Glendale, California
# 4           Redding, California
# ...                         ...
# 2277  Highland Park, New Jersey
# 2278             Taipei, Taiwan
# 2279      Branford, Connecticut
# 2280      San Diego, California
# 2281     San Rafael, California
#
#                                                  origin         roast  \
# 0                  Piendamó, Cauca Department, Colombia  Medium-Light
# 1        Trujillo, Valle del Cauca Department, Colombia         Light
# 2         Yirgacheffe growing region, southern Ethiopia  Medium-Light
# 3                                      Tolima, Colombia  Medium-Light
# 4                 Volcan growing region, western Panama         Light
# ...                                                 ...           ...
# 2277                       Biolley, southern Costa Rica  Medium-Light
# ...

# %%
df3 = pd.concat([df2.id1, df2.id2]).reset_index()
df1 = df2.merge(df3, how="left", left_on = df1.ID, right_on = df3[0])
df1 = df1.iloc[:, :2]
df1 = df1.rename(columns={"key_0": "ID"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/d0/kyjzvmwn3fdgc5m0t8snt0nm0000gn/T/ipykernel_30209/3378016176.py in <module>
# ----> 1 df3 = pd.concat([df2.id1, df2.id2]).reset_index()
#       2 df1 = df2.merge(df3, how="left", left_on = df1.ID, right_on = df3[0])
#       3 df1 = df1.iloc[:, :2]
#       4 df1 = df1.rename(columns={"key_0": "ID"})
#
# NameError: name 'df2' is not defined

# %%
result_df = pd.merge(Base, sim_cof, left_on=['B', 'C'], right_on=['E', 'F'])
