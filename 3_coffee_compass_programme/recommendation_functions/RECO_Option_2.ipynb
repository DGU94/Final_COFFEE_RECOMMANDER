# %% [markdown]
# RECOMMANDATION PROGRAMME - Option 2

# %%
import pandas as pd

# %%
data= pd.read_csv('/Users/david/Documents/GitHub/Final_project_DGU_LDU_COFFEE/2_EDA/NLP/most_frequent_categories.csv')
data
# Out:
#       Unnamed: 0                              name  \
# 0              0          Ethiopia Shakiso Mormora
# 1              1                Ethiopia Suke Quto
# 2              2        Ethiopia Gedeb Halo Beriti
# 3              3           Ethiopia Kayon Mountain
# 4              4  Ethiopia Gelgelu Natural Organic
# ...          ...                               ...
# 1241        1241                    Finca Patzibir
# 1242        1242                   Proyecto Aurora
# 1243        1243                  Finca El Potrero
# 1244        1244          Chacayá Santiago Atitlán
# 1245        1245                    Espresso No. 3
#
#                          roaster         roast    loc_country     origin  \
# 0                   Revel Coffee  Medium-Light  United States   Ethiopia
# 1                    Roast House  Medium-Light  United States   Ethiopia
# 2      Big Creek Coffee Roasters        Medium  United States   Ethiopia
# ...

# %% [markdown]
# **Based on top rated coffee**

# %%
# Top 5 rated coffee :
sort_rate = data.sort_values('rating', ascending=False).head(5)
sort_rate
# We pick one random from them :
print('On random top 5 rated coffee is :')
sort_rate.sample(1)
# Out:
# On random top 5 rated coffee is :
#      Unnamed: 0                             name                    roaster  \
# 229         229  Panama Ninety Plus Perci Lot 50  Bird Rock Coffee Roasters
#
#             roast    loc_country  origin  100g_USD  rating   review_date  \
# 229  Medium-Light  United States  Panama     26.46      97  January 2019
#
#                                                 review  ...  Candy_count  \
# 229  Wild, unruly, utterly brilliant and original. ...  ...            0
#
#      Nutty_count  Creamy_count  Herbal_count  Chocolaty_count  Floral_count  \
# 229            1             0             0                2             4
#
#      Texture_count  Character_count  Acidity / Spicy_count  max_match_key
# 229              3                0                      0          Sweet
#
# [1 rows x 26 columns]

# %% [markdown]
# **Top rating coffee among cheapest price**

# %%
sort_cheap = data.sort_values('100g_USD', ascending=True).head(5)
best_cheap= sort_cheap.sort_values('rating', ascending=False).head(1)

print('the best value price coffee is :')
best_cheap
# Out:
# the best value price coffee is :
#       Unnamed: 0                                   name        roaster  \
# 1225        1225  Taiwan Natural Alishan Zhuo-Wu Geisha  Kakalove Cafe
#
#              roast loc_country  origin  100g_USD  rating   review_date  \
# 1225  Medium-Light      Taiwan  Taiwan      1.36      95  October 2022
#
#                                                  review  ...  Candy_count  \
# 1225  Richly fruit-toned, deeply chocolaty. Dried ra...  ...            0
#
#       Nutty_count  Creamy_count  Herbal_count  Chocolaty_count  Floral_count  \
# 1225            0             0             0                2             0
#
#       Texture_count  Character_count  Acidity / Spicy_count  max_match_key
# 1225              4                0                      2        Texture
#
# [1 rows x 26 columns]
